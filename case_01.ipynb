# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()

df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

df['species'] = pd.Categorical.from_codes(
    iris.target,
    iris.target_names
)

print(f"数据维度：{df.shape}")
print(f"特征列：{list(df.columns)}")

df.head()
# Out:
# 数据维度：(150, 5)
# 特征列：['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)', 'species']
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
# 左图：各品种的花瓣长度分布
sns.boxplot(data=df, x='species', y='petal length (cm)', ax=axes[0])
axes[0].set_title('花瓣长度分布')
# 右图：花萼长度 vs 花瓣长度
sns.scatterplot(data=df, x='sepal length (cm)', y='petal length (cm)', hue='species', style='species', s=60, ax=axes[1])
axes[1].set_title('花萼长度 vs 花瓣长度')
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score


X_train, X_test, y_train, y_test = train_test_split(
    iris.data, iris.target, test_size=0.3, random_state=42
)


knn = KNeighborsClassifier(n_neighbors=3)

knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)


print(f"准确率: {accuracy_score(y_test, y_pred):.1%}")
# Out:
# 准确率: 100.0%
